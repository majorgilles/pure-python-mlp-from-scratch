# %% [markdown]
# # Bike rental demand regression
#
# In this notebook, we will use the curated mini bike-rental dataset to train a small pure-Python MLP to predict rental demand.
#
# For now, this is only a bare starter notebook: one intro cell and one code cell.

# %%
from pathlib import Path

DATA_PATH = Path("../data/bike_rentals_mini.csv")
print(f"Dataset path: {DATA_PATH}")
